# %% [markdown]
# # 1.4.5 Morphological Transformations

# %% [markdown]
# ## 1. Erosion

# %%
import cv2
import numpy as np

# %%
def showImage(img):
    cv2.imshow('image',img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
img = cv2.imread('image01.jpg',0)
img = 255-img;
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 img = cv2.imread('image01.jpg',0)
#       2 img = 255-img
#
# NameError: name 'cv2' is not defined

# %%
showImage(img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 showImage(img)
#
# Cell In[55], line 2, in showImage(img)
#       1 def showImage(img):
# ----> 2     cv2.imshow('/C:/Users/U303-40/Desktop/ip2026/lena.png',img)
#       3     cv2.waitKey(0)
#       4     cv2.destroyAllWindows()
#
# error: OpenCV(4.13.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:973: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %%
kernel = np.ones((3,3),np.uint8)
erosion = cv2.erode(img,kernel,iterations = 1)

# %%
showImage(erosion)

# %% [markdown]
# ## 2. Dilation

# %%
kernel = np.ones((3,3),np.uint8)
dilation = cv2.dilate(img,kernel,iterations = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 kernel = np.ones((3,3),np.uint8)
#       2 dilation = cv2.dilate(img,kernel,iterations = 1)
#
# NameError: name 'np' is not defined

# %%
showImage(dilation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 showImage(dilation)
#
# NameError: name 'showImage' is not defined

# %% [markdown]
# ## 3. Opening

# %%
height, width = img.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 height, width = img.shape
#
# NameError: name 'img' is not defined

# %%
img = cv2.imread('./Char/image01.jpg',0)
img = 255-img;
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 img = cv2.imread('./Char/image01.jpg',0)
# ----> 2 img = 255-img
#
# TypeError: unsupported operand type(s) for -: 'int' and 'NoneType'

# %%
m = 1
noise_img = img.copy()
for i in range(100):
    x = np.random.randint(width)
    y = np.random.randint(height)
    noise_img[y-m:y+m,x-m:x+m]=255

# %%
showImage(noise_img)

# %%
kernel = np.ones((3,3),np.uint8)
opening = cv2.morphologyEx(noise_img, cv2.MORPH_OPEN, kernel)

# %%
showImage(opening)

# %% [markdown]
# ## 4. Closing

# %%
img = cv2.imread('./Char/image01.jpg',0)
img = 255-img;
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 img = cv2.imread('./Char/image01.jpg',0)
# ----> 2 img = 255-img
#
# TypeError: unsupported operand type(s) for -: 'int' and 'NoneType'

# %%
m = 1
noise_img = img.copy()
for i in range(1000):
    x = np.random.randint(width)
    y = np.random.randint(height)
    noise_img[y-m:y+m,x-m:x+m]=0
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 2
#       1 m = 1
# ----> 2 noise_img = img.copy()
#       3 for i in range(1000):
#       4     x = np.random.randint(width)
#
# AttributeError: 'NoneType' object has no attribute 'copy'

# %%
showImage(noise_img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 showImage(noise_img)
#
# NameError: name 'noise_img' is not defined

# %%
kernel = np.ones((3,3),np.uint8)
closing = cv2.morphologyEx(noise_img, cv2.MORPH_CLOSE, kernel)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 kernel = np.ones((3,3),np.uint8)
# ----> 2 closing = cv2.morphologyEx(noise_img, cv2.MORPH_CLOSE, kernel)
#
# NameError: name 'noise_img' is not defined

# %%
showImage(closing)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 showImage(closing)
#
# NameError: name 'closing' is not defined

# %% [markdown]
# ## 5. Morphological Gradient

# %%
img = cv2.imread('./Char/image01.jpg',0)
img = 255-img;

# %%
kernel = np.ones((3,3),np.uint8)
gradient = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel)

# %%
showImage(gradient)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-518c62fa4baa> in <module>
# ----> 1 showImage(gradient)
#
# NameError: name 'showImage' is not defined
