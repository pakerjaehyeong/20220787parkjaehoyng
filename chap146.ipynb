# %% [markdown]
# # 1.4.6 Image Gradient

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('sIMG_2164.jpg',0)
laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)

# %%
plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5, 1.0, 'Sobel Y'), ([], []), ([], []))

# %%
img = np.random.randint(10, size=(12,12))
#img = np.ones((10,10),np.float32)

# %%
img
# Out:
# array([[0, 0, 9, 0, 1, 2, 9, 4, 9, 6, 6, 9],
#        [3, 9, 1, 6, 4, 2, 7, 0, 3, 7, 7, 1],
#        [3, 7, 2, 5, 4, 1, 1, 5, 5, 6, 3, 7],
#        [6, 9, 0, 7, 1, 3, 0, 3, 3, 8, 0, 6],
#        [0, 2, 0, 4, 4, 1, 9, 1, 9, 1, 5, 7],
#        [2, 5, 2, 1, 6, 2, 3, 7, 0, 5, 7, 0],
#        [8, 2, 8, 6, 7, 8, 8, 6, 6, 9, 6, 9],
#        [4, 9, 3, 2, 8, 1, 4, 2, 8, 0, 5, 6],
#        [7, 5, 9, 9, 3, 0, 7, 0, 3, 4, 8, 9],
#        [1, 6, 4, 4, 0, 2, 5, 1, 7, 3, 8, 4],
#        [9, 0, 0, 0, 9, 0, 0, 7, 3, 4, 6, 7],
#        [5, 3, 0, 7, 1, 2, 6, 1, 5, 7, 8, 6]])

# %%
h,w=img.shape

# %%
print(h,w)
# Out:
# 12 12
