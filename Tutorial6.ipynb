# %% [markdown]
# #####  Loop

# %%
for someChar in "Hello World":
    print (someChar)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 if x == 3:
#       2     print ("X equals 3.")
#       3 elif x == 2:
#
# NameError: name 'x' is not defined
