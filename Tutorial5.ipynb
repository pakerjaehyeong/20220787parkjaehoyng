# %%
if x == 3:
    print ("X equals 3.")
elif x == 2:
    print ("X equals 2.")
else:
    print ("X equals something else.")
print ("This is outside the ‘if’.")
# Out:
# X equals something else.
# This is outside the ‘if’.

# %%
x = 3

# %%
while x < 5:
    print(x, "still in the loop")
    x = x + 1
# Out:
# 3 still in the loop
# 4 still in the loop

# %%
x = 6
while x < 5:
    print (x, "still in the loop")

# %%
number_of_plyers = 2
assert (number_of_plyers < 5)
