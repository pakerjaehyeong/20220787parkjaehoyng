# %% [markdown]
# #####  Control Flow

# %%
x = 3
while x < 15:
    print(x, "still in the loop") 
    x = x + 1

x = 6
while x < 5:
    print(x, "still in the loop")
# Out:
# 3 still in the loop
# 4 still in the loop
# 5 still in the loop
# 6 still in the loop
# 7 still in the loop
# 8 still in the loop
# 9 still in the loop
# 10 still in the loop
# 11 still in the loop
# 12 still in the loop
# 13 still in the loop
# 14 still in the loop

# %%
assert(number_of_players < 5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 assert(number_of_players < 5)
#
# NameError: name 'number_of_players' is not defined
